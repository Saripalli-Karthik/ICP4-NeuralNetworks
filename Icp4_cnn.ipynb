# %% [markdown]
# <a href="https://colab.research.google.com/github/Saripalli-Karthik/ICP4-NeuralNetworks/blob/main/Icp4_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# given class Code after correcting errors

# %%
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from tensorflow.keras.constraints import MaxNorm
from keras.optimizers.legacy import SGD
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from tensorflow.keras.utils import to_categorical
#from keras import backend as K
#K.set_image_dim_ordering('th')

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0
# one hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]
# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile model
epochs = 25
lrate = 0.01
decay = lrate/epochs
sgd = SGD(learning_rate=lrate,momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 19s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4210090 (16.06 MB)
# Trainable params: 4210090 (16.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1563/1563 [==============================] - 16s 7ms/step - loss: 1.7256 - accuracy: 0.3751 - val_loss: 1.4151 - val_accuracy: 0.4921
# Epoch 2/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.3826 - accuracy: 0.5024 - val_loss: 1.2364 - val_accuracy: 0.5547
# Epoch 3/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2022 - accuracy: 0.5708 - val_loss: 1.1089 - val_accuracy: 0.6058
# Epoch 4/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0685 - accuracy: 0.6242 - val_loss: 1.0498 - val_accuracy: 0.6316
# Epoch 5/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9610 - accuracy: 0.6621 - val_loss: 0.9852 - val_accuracy: 0.6488
# Epoch 6/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8772 - accuracy: 0.6885 - val_loss: 0.9545 - val_accuracy: 0.6646
# Epoch 7/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7982 - accuracy: 0.7185 - val_loss: 0.9496 - val_accuracy: 0.6678
# Epoch 8/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7319 - accuracy: 0.7418 - val_loss: 0.9309 - val_accuracy: 0.6788
# Epoch 9/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6704 - accuracy: 0.7628 - val_loss: 0.9123 - val_accuracy: 0.6891
# Epoch 10/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6155 - accuracy: 0.7812 - val_loss: 0.9234 - val_accuracy: 0.6894
# Epoch 11/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5679 - accuracy: 0.7984 - val_loss: 0.9324 - val_accuracy: 0.6924
# Epoch 12/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5260 - accuracy: 0.8153 - val_loss: 0.9271 - val_accuracy: 0.7003
# Epoch 13/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4829 - accuracy: 0.8291 - val_loss: 0.9456 - val_accuracy: 0.6949
# Epoch 14/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4518 - accuracy: 0.8398 - val_loss: 0.9513 - val_accuracy: 0.7054
# Epoch 15/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4166 - accuracy: 0.8545 - val_loss: 0.9695 - val_accuracy: 0.7014
# Epoch 16/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3874 - accuracy: 0.8629 - val_loss: 0.9711 - val_accuracy: 0.6994
# Epoch 17/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3604 - accuracy: 0.8733 - val_loss: 0.9861 - val_accuracy: 0.7029
# Epoch 18/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3381 - accuracy: 0.8810 - val_loss: 0.9981 - val_accuracy: 0.7010
# Epoch 19/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3150 - accuracy: 0.8892 - val_loss: 1.0174 - val_accuracy: 0.7014
# Epoch 20/25
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2975 - accuracy: 0.8960 - val_loss: 1.0085 - val_accuracy: 0.7036
# Epoch 21/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2790 - accuracy: 0.9023 - val_loss: 1.0546 - val_accuracy: 0.7051
# Epoch 22/25
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2711 - accuracy: 0.9058 - val_loss: 1.0486 - val_accuracy: 0.7042
# Epoch 23/25
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2490 - accuracy: 0.9143 - val_loss: 1.0730 - val_accuracy: 0.7011
# Epoch 24/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2375 - accuracy: 0.9176 - val_loss: 1.0516 - val_accuracy: 0.7101
# Epoch 25/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2231 - accuracy: 0.9247 - val_loss: 1.0820 - val_accuracy: 0.7034
# Accuracy: 70.34%

# %% [markdown]
# Code after adding all necessary layers to the model as per requirements

# %%
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from tensorflow.keras.constraints import MaxNorm
from keras.optimizers.legacy import SGD
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from tensorflow.keras.utils import to_categorical
#from keras import backend as K
#K.set_image_dim_ordering('th')

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0
# one hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]
# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128,(3,3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(128,(3,3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
# Compile model
epochs = 25
lrate = 0.01
decay = lrate/epochs
sgd = SGD(learning_rate=lrate,momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        896
#
#  dropout_7 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  dropout_8 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dropout_9 (Dropout)         (None, 2048)              0
#
#  dense_5 (Dense)             (None, 1024)              2098176
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2878186 (10.98 MB)
# Trainable params: 2878186 (10.98 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1563/1563 [==============================] - 15s 8ms/step - loss: 1.8125 - accuracy: 0.3319 - val_loss: 1.4692 - val_accuracy: 0.4729
# Epoch 2/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3678 - accuracy: 0.5030 - val_loss: 1.1854 - val_accuracy: 0.5743
# Epoch 3/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1510 - accuracy: 0.5869 - val_loss: 1.0381 - val_accuracy: 0.6318
# Epoch 4/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9946 - accuracy: 0.6442 - val_loss: 0.8910 - val_accuracy: 0.6934
# Epoch 5/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8817 - accuracy: 0.6869 - val_loss: 0.8502 - val_accuracy: 0.7048
# Epoch 6/25
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.7959 - accuracy: 0.7197 - val_loss: 0.7676 - val_accuracy: 0.7359
# Epoch 7/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7310 - accuracy: 0.7427 - val_loss: 0.7483 - val_accuracy: 0.7376
# Epoch 8/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6793 - accuracy: 0.7598 - val_loss: 0.7160 - val_accuracy: 0.7546
# Epoch 9/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6303 - accuracy: 0.7779 - val_loss: 0.6841 - val_accuracy: 0.7660
# Epoch 10/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5914 - accuracy: 0.7909 - val_loss: 0.6832 - val_accuracy: 0.7667
# Epoch 11/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5568 - accuracy: 0.8022 - val_loss: 0.6608 - val_accuracy: 0.7707
# Epoch 12/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5310 - accuracy: 0.8098 - val_loss: 0.6537 - val_accuracy: 0.7768
# Epoch 13/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4967 - accuracy: 0.8244 - val_loss: 0.6519 - val_accuracy: 0.7751
# Epoch 14/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4743 - accuracy: 0.8315 - val_loss: 0.6404 - val_accuracy: 0.7818
# Epoch 15/25
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.4471 - accuracy: 0.8407 - val_loss: 0.6425 - val_accuracy: 0.7836
# Epoch 16/25
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.4294 - accuracy: 0.8462 - val_loss: 0.6289 - val_accuracy: 0.7866
# Epoch 17/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4093 - accuracy: 0.8550 - val_loss: 0.6217 - val_accuracy: 0.7889
# Epoch 18/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3885 - accuracy: 0.8620 - val_loss: 0.6285 - val_accuracy: 0.7887
# Epoch 19/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3719 - accuracy: 0.8679 - val_loss: 0.6417 - val_accuracy: 0.7894
# Epoch 20/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3620 - accuracy: 0.8710 - val_loss: 0.6309 - val_accuracy: 0.7933
# Epoch 21/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3432 - accuracy: 0.8782 - val_loss: 0.6438 - val_accuracy: 0.7923
# Epoch 22/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3351 - accuracy: 0.8801 - val_loss: 0.6283 - val_accuracy: 0.7981
# Epoch 23/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3145 - accuracy: 0.8875 - val_loss: 0.6315 - val_accuracy: 0.7993
# Epoch 24/25
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3038 - accuracy: 0.8910 - val_loss: 0.6430 - val_accuracy: 0.7997
# Epoch 25/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2954 - accuracy: 0.8952 - val_loss: 0.6281 - val_accuracy: 0.8021
# Accuracy: 80.21%

# %% [markdown]
# Predict the first 4 images of the test data using the above model. Then, compare with the actual label for those 4
# images to check whether or not the model has predicted correctly.

# %%
import matplotlib.pyplot as plt
import numpy as np

predictions = model.predict(X_test[:4])

# Convert predictions from one-hot encoding to class labels
predicted_classes = np.argmax(predictions, axis=1)

# Get the actual class labels for the first 4 images
actual_classes = np.argmax(y_test[:4], axis=1)

def plot_images(images, labels, predictions):
    fig, axes = plt.subplots(1, 4, figsize=(12, 3))
    for i in range(4):
        axes[i].imshow(images[i])
        axes[i].set_title(f"Predicted: {predictions[i]}\nActual: {labels[i]}")
        axes[i].axis('off')
    plt.show()

plot_images(X_test[:4], actual_classes, predicted_classes)

# Print out the actual and predicted labels for comparison
for i in range(4):
    print(f"Image {i+1}:")
    print(f"Predicted label: {predicted_classes[i]}")
    print(f"Actual label: {actual_classes[i]}")
    print()
# Out:
# 1/1 [==============================] - 0s 468ms/step
# Image 1:
# Predicted label: 3
# Actual label: 3
#
# Image 2:
# Predicted label: 8
# Actual label: 8
#
# Image 3:
# Predicted label: 8
# Actual label: 8
#
# Image 4:
# Predicted label: 0
# Actual label: 0

# %% [markdown]
# Visualize Loss and Accuracy using the history object

# %%
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
